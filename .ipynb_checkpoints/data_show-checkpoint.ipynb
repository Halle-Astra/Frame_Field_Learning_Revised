# %%
from matplotlib import pyplot as plt 
import numpy as np 
import json 
from pycocotools.coco import COCO
import os 
# %matplotlib inline

# %%
root = '/data/sda/datasets/Datasets4FFL/mapping_challenge_dataset/raw/val'
froot = os.path.join(root,'annotation.json')

coco = COCO(froot)
# Out:
# loading annotations into memory...
# Done (t=4.07s)
# creating index...
# index created!

# %%
img_ls = coco.loadImgs(ids=[0])

# %%
imgname = img_ls[0]['file_name']

# %%
help(coco.getAnnIds)
# Out:
# Help on method getAnnIds in module pycocotools.coco:
#
# getAnnIds(imgIds=[], catIds=[], areaRng=[], iscrowd=None) method of pycocotools.coco.COCO instance
#     Get ann ids that satisfy given filter conditions. default skips that filter
#     :param imgIds  (int array)     : get anns for given imgs
#            catIds  (int array)     : get anns for given cats
#            areaRng (float array)   : get anns for given area range (e.g. [0 inf])
#            iscrowd (boolean)       : get anns for given crowd label (False or True)
#     :return: ids (int array)       : integer array of ann ids

# %%
ann_ids = coco.getAnnIds(imgIds = [0])

# %%
ann_ls = coco.loadAnns(ids = ann_ids)

# %%
img = plt.imread(os.path.join(root,'images',imgname))
plt.imshow(img)

for ann_dict in ann_ls:
    ann = ann_dict['segmentation']
    ann = np.array(ann).reshape(-1,2)
    plt.plot(ann[:,0],ann[:,1],'b')
    
    bbox = ann_dict['bbox']
    y,x,y1,x1 = bbox
    bbox_xyxy = [[x,y],[x1,y1]]
    bbox_xyxy = np.array(bbox_xyxy).reshape(-1,2)
    
    plt.imshow(img)
    
    plt.plot(bbox_xyxy[:,0],bbox_xyxy[:,1],'r-*')
    plt.title(bbox)
    plt.show()

# %%
ann_ls
# Out:
# [{'id': 9,
#   'image_id': 0,
#   'segmentation': [[13.000000000000014,
#     261.0,
#     13.000000000000012,
#     257.0,
#     15.000000000000007,
#     215.00000000000003,
#     75.00000000000001,
#     217.0,
#     74.00000000000001,
#     259.0,
#     65.00000000000001,
#     258.0,
#     65.00000000000001,
#     262.0,
#     13.000000000000014,
#     261.0]],
#   'area': 2731.0,
#   'bbox': [13.000000000000012, 13.000000000000012, 248.0, 62.0],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 8,
#   'image_id': 0,
#   'segmentation': [[97.00000000000001,
#     258.0,
#     98.00000000000001,
#     220.0,
#     122.00000000000001,
#     220.0,
#     122.00000000000001,
#     212.0,
#     161.0,
#     213.0,
#     161.0,
#     221.0,
#     160.0,
#     239.0,
#     149.0,
#     239.0,
#     149.0,
#     259.0,
#     149.0,
#     262.0,
#     97.00000000000001,
#     262.0,
#     97.00000000000001,
#     258.0]],
#   'area': 2677.0,
#   'bbox': [97.00000000000001, 97.00000000000001, 161.0, 63.999999999999986],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 2,
#   'image_id': 0,
#   'segmentation': [[82.0,
#     112.0,
#     71.0,
#     111.0,
#     71.0,
#     119.0,
#     52.99999999999999,
#     118.0,
#     58.999999999999986,
#     55.0,
#     81.99999999999999,
#     57.0,
#     82.99999999999999,
#     44.0,
#     120.99999999999999,
#     47.0,
#     119.99999999999999,
#     59.0,
#     125.99999999999999,
#     59.0,
#     120.0,
#     122.0,
#     82.0,
#     119.0,
#     82.0,
#     112.0]],
#   'area': 4594.0,
#   'bbox': [52.99999999999999, 52.99999999999999, 66.0, 73.0],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 4,
#   'image_id': 0,
#   'segmentation': [[212.0,
#     113.0,
#     215.0,
#     71.0,
#     228.0,
#     71.0,
#     228.0,
#     60.0,
#     258.0,
#     61.0,
#     257.0,
#     73.0,
#     274.0,
#     72.99999999999997,
#     271.0,
#     122.99999999999997,
#     223.0,
#     121.0,
#     224.0,
#     114.0,
#     212.0,
#     113.0]],
#   'area': 3207.0,
#   'bbox': [60.0, 212.0, 198.0, 62.0],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 0,
#   'image_id': 0,
#   'segmentation': [[291.0,
#     4.999999999999972,
#     291.0,
#     -2.842170943040401e-14,
#     300.0,
#     -2.842170943040401e-14,
#     300.0,
#     4.999999999999972,
#     291.0,
#     4.999999999999972]],
#   'area': 45.0,
#   'bbox': [-2.842170943040401e-14, 291.0, 300.0, 9.0],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 3,
#   'image_id': 0,
#   'segmentation': [[132.0,
#     118.0,
#     134.0,
#     59.0,
#     142.0,
#     59.0,
#     142.0,
#     47.0,
#     163.0,
#     47.0,
#     162.0,
#     59.0,
#     198.0,
#     60.0,
#     196.0,
#     120.0,
#     183.0,
#     119.0,
#     183.0,
#     114.0,
#     169.0,
#     114.0,
#     169.0,
#     119.0,
#     169.0,
#     122.0,
#     132.0,
#     121.0,
#     132.0,
#     118.0]],
#   'area': 4099.0,
#   'bbox': [47.0, 132.0, 151.0, 66.0],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 1,
#   'image_id': 0,
#   'segmentation': [[-1.0899356512411444e-14,
#     61.00000000000003,
#     27.99999999999999,
#     62.00000000000003,
#     26.99999999999999,
#     76.00000000000003,
#     43.99999999999999,
#     77.0,
#     42.99999999999999,
#     118.0,
#     -4.0413344371862654e-15,
#     117.00000000000003,
#     -1.0899356512411444e-14,
#     61.00000000000003]],
#   'area': 2196.0,
#   'bbox': [-1.0899356512411444e-14,
#    -1.0899356512411444e-14,
#    76.00000000000004,
#    44.00000000000001],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 5,
#   'image_id': 0,
#   'segmentation': [[278.0,
#     123.99999999999997,
#     279.0,
#     72.99999999999997,
#     300.0,
#     72.99999999999997,
#     300.0,
#     123.99999999999997,
#     278.0,
#     123.99999999999997]],
#   'area': 1097.0,
#   'bbox': [72.99999999999997, 278.0, 227.00000000000003, 22.0],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 7,
#   'image_id': 0,
#   'segmentation': [[170.0,
#     260.0,
#     171.0,
#     219.0,
#     230.0,
#     220.0,
#     229.0,
#     261.0,
#     170.0,
#     260.0]],
#   'area': 2420.0,
#   'bbox': [170.0, 170.0, 90.0, 60.0],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 6,
#   'image_id': 0,
#   'segmentation': [[7.225416114969383e-15,
#     209.00000000000003,
#     3.000000000000007,
#     209.00000000000003,
#     3.000000000000013,
#     255.00000000000003,
#     1.2858791391047208e-14,
#     255.00000000000003,
#     7.225416114969383e-15,
#     209.00000000000003]],
#   'area': 138.0,
#   'bbox': [7.225416114969383e-15,
#    7.225416114969383e-15,
#    209.00000000000003,
#    3.0000000000000058],
#   'category_id': 100,
#   'iscrowd': 0},
#  {'id': 10,
#   'image_id': 0,
#   'segmentation': [[247.0,
#     266.0,
#     250.0,
#     220.0,
#     300.0,
#     220.99999999999997,
#     300.0,
#     268.0,
#     247.0,
#     266.0]],
#   'area': 2397.0,
#   'bbox': [220.0, 247.0, 80.0, 53.0],
#   'category_id': 100,
#   'iscrowd': 0}]
